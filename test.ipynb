# %%
import polars as pl

from pbstats import statcast

pl.Config.set_tbl_cols = 1000

# %%
df = statcast.statcast(start_dt="2021-04-01", end_dt="2021-04-02", extra_stats=True)
# Out:
# Pulling data for date range: 2021-04-01 to 2021-04-02.
# ...
# Processing extra data: 100%|██████████| 2/2 [00:00<00:00, 281.37it/s]

# %%
df.head(20)
# Out:
# shape: (20, 249)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ pitch_typ ┆ game_date ┆ release_s ┆ release_p ┆ … ┆ xslgdiff_ ┆ wobadiff_ ┆ swing_mis ┆ arm_angl │
# │ e         ┆ ---       ┆ peed      ┆ os_x      ┆   ┆ batter    ┆ batter    ┆ s_percent ┆ e_batter │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ _batter   ┆ ---      │
# │ str       ┆           ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ FF        ┆ 2021-04-0 ┆ 86.8      ┆ 2.17      ┆ … ┆ 0.019     ┆ 0.005     ┆ 17.6      ┆ 37.4     │
# │           ┆ 1         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %%
df.describe()
# Out:
# shape: (9, 250)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ statistic ┆ pitch_typ ┆ game_date ┆ release_s ┆ … ┆ xslgdiff_ ┆ wobadiff_ ┆ swing_mis ┆ arm_angl │
# │ ---       ┆ e         ┆ ---       ┆ peed      ┆   ┆ batter    ┆ batter    ┆ s_percent ┆ e_batter │
# │ str       ┆ ---       ┆ str       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ _batter   ┆ ---      │
# │           ┆ str       ┆           ┆ f64       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ count     ┆ 6333      ┆ 6333      ┆ 6333.0    ┆ … ┆ 4368.0    ┆ 4368.0    ┆ 4368.0    ┆ 4368.0   │
# │ null_coun ┆ 0         ┆ 0         ┆ 0.0       ┆ … ┆ 1965.0    ┆ 1965.0    ┆ 1965.0    ┆ 1965.0   │
# ...
