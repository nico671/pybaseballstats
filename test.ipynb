# %% [markdown]
# # Statcast Single Game

# %%
from src.pybaseballstats.statcast import statcast_single_game

# %%
df = statcast_single_game(game_pk=529406, extra_stats=True)
# Out:
# ...
# Processing extra data: 100%|██████████| 2/2 [00:00<00:00, 7612.17it/s]
# Joining data.
# Done

# %%
df = df.collect()

# %%
df
# Out:
# shape: (277, 249)
# ┌───────────┬───────────┬───────────┬───────────┬───┬───────────┬───────────┬───────────┬──────────┐
# │ pitch_typ ┆ game_date ┆ release_s ┆ release_p ┆ … ┆ xslgdiff_ ┆ wobadiff_ ┆ swing_mis ┆ arm_angl │
# │ e         ┆ ---       ┆ peed      ┆ os_x      ┆   ┆ batter    ┆ batter    ┆ s_percent ┆ e_batter │
# │ ---       ┆ str       ┆ ---       ┆ ---       ┆   ┆ ---       ┆ ---       ┆ _batter   ┆ ---      │
# │ str       ┆           ┆ f64       ┆ f64       ┆   ┆ f64       ┆ f64       ┆ ---       ┆ f64      │
# │           ┆           ┆           ┆           ┆   ┆           ┆           ┆ f64       ┆          │
# ╞═══════════╪═══════════╪═══════════╪═══════════╪═══╪═══════════╪═══════════╪═══════════╪══════════╡
# │ FF        ┆ 2018-03-2 ┆ 92.8      ┆ 3.29      ┆ … ┆ null      ┆ null      ┆ null      ┆ null     │
# │           ┆ 9         ┆           ┆           ┆   ┆           ┆           ┆           ┆          │
# ...

# %% [markdown]
# # Fangraphs Batting

# %%
from src.pybaseballstats import fangraphs_batting_range

# %%
df = fangraphs_batting_range(start_date="2019-03-28", end_date="2019-03-31")
# Out:
# Fetching data: 100%|██████████| 26/26 [00:02<00:00,  9.44it/s]

# %%
df
# Out:
# shape: (129, 313)
# ┌───────────────────────┬──────┬─────┬─────────┬───┬─────────┬──────────┬───────┬───────┐
# │ Name                  ┆ Team ┆ PA  ┆ pfxFA-Z ┆ … ┆ HardHit ┆ HardHit% ┆ xAVG  ┆ xSLG  │
# │ ---                   ┆ ---  ┆ --- ┆ ---     ┆   ┆ ---     ┆ ---      ┆ ---   ┆ ---   │
# │ str                   ┆ str  ┆ i64 ┆ f64     ┆   ┆ i64     ┆ f64      ┆ f64   ┆ f64   │
# ╞═══════════════════════╪══════╪═════╪═════════╪═══╪═════════╪══════════╪═══════╪═══════╡
# │ Aaron Judge           ┆ NYY  ┆ 704 ┆ 9.5     ┆ … ┆ 238     ┆ 60.9     ┆ 0.31  ┆ 0.723 │
# │ Juan Soto             ┆ NYY  ┆ 713 ┆ 9.5     ┆ … ┆ 262     ┆ 56.8     ┆ 0.316 ┆ 0.646 │
# │ Shohei Ohtani         ┆ LAD  ┆ 731 ┆ 8.7     ┆ … ┆ 287     ┆ 59.5     ┆ 0.314 ┆ 0.66  │
# │ Yordan Alvarez        ┆ HOU  ┆ 635 ┆ 9.5     ┆ … ┆ 229     ┆ 49.7     ┆ 0.303 ┆ 0.595 │
# │ Vladimir Guerrero Jr. ┆ TOR  ┆ 697 ┆ 9.5     ┆ … ┆ 287     ┆ 54.8     ┆ 0.321 ┆ 0.567 │
# ...

# %% [markdown]
# # Fangraphs Fielding

# %%
from src.pybaseballstats.fangraphs import fangraphs_fielding_range

# %%
df = fangraphs_fielding_range(start_date="2019-03-28", end_date="2019-03-31")
# Out:
# Fetching data: 100%|██████████| 3/3 [00:01<00:00,  1.57it/s]

# %%
df.shape
# Out:
# (112, 46)

# %% [markdown]
# # Fangraphs Pitching

# %%
from src.pybaseballstats import fangraphs_pitching_range

# %%
df = fangraphs_pitching_range(
    start_date="2019-03-28", end_date="2019-03-31", stat_types=None
)
df.shape
# Out:
# Fetching data:   0%|          | 0/32 [00:00<?, ?it/s]
# Task exception was never retrieved
# future: <Task finished name='Task-104' coro=<get_table_data_async() done, defined at /Users/nicocarbone/Documents/dev/pybaseballstats/src/pybaseballstats/utils/fangraphs_utils.py:333> exception=KeyError('starter_reliever')>
# Traceback (most recent call last):
#   File "/Users/nicocarbone/.local/share/uv/python/cpython-3.13.0-macos-aarch64-none/lib/python3.13/asyncio/tasks.py", line 304, in __step_run_and_handle_result
#     result = coro.send(None)
#   File "/Users/nicocarbone/Documents/dev/pybaseballstats/src/pybaseballstats/utils/fangraphs_utils.py", line 350, in get_table_data_async
#         session,
#         ^^^^^^^^
#     ...<13 lines>...
#     for stat in stat_types
#
#   File "/Users/nicocarbone/Documents/dev/pybaseballstats/src/pybaseballstats/utils/fangraphs_utils.py", line 219, in _construct_url
# KeyError: 'starter_reliever'
# Task exception was never retrieved
# ...
